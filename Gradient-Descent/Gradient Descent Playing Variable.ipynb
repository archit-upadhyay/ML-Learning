# %%
## Gradient Descent Algo with Tolerance - Question 3 Trial
import numpy as np
import matplotlib.pyplot as plt

def cost_func(x):
  return ((x**2)-(4*x)+3)

def grad_slope(x):
  return (2*x) - 4


x = 10
print("Value of x:",x)
alpha = 0.1
num_iters = 100
x_values = []
Improve_values = []
cost_values = []
ltol = 0.000001
rtol = -0.000001
i=0

while(True):
  cost = cost_func(x)
  grad = grad_slope(x)
  cost_values.append(cost)
  Improve_values.append(alpha * grad)
  x = x - alpha * grad
  x_values.append(x)
  i+=1
  if(alpha * grad < ltol) and (alpha * grad > 0):
    break
  if(alpha * grad > rtol) and (alpha * grad < 0):
    break

  
print(x_values)
print(Improve_values)
print(cost_values)
print(i)

plt.plot(x_values)
plt.plot(Improve_values)
plt.plot(cost_values)
# Out:
# Value of x: 10
# [8.4, 7.12, 6.096, 5.2768, 4.62144, 4.0971519999999995, 3.6777215999999995, 3.3421772799999996, 3.073741824, 2.8589934591999997, 2.68719476736, 2.549755813888, 2.4398046511104, 2.35184372088832, 2.2814749767106557, 2.2251799813685245, 2.1801439850948197, 2.1441151880758555, 2.1152921504606845, 2.0922337203685477, 2.073786976294838, 2.0590295810358703, 2.0472236648286963, 2.037778931862957, 2.0302231454903654, 2.0241785163922925, 2.019342813113834, 2.015474250491067, 2.0123794003928537, 2.0099035203142828, 2.007922816251426, 2.006338253001141, 2.0050706024009126, 2.0040564819207303, 2.003245185536584, 2.002596148429267, 2.0020769187434135, 2.0016615349947307, 2.0013292279957846, 2.0010633823966275, 2.000850705917302, 2.000680564733842, 2.0005444517870736, 2.0004355614296587, 2.000348449143727, 2.0002787593149813, 2.000223007451985, 2.000178405961588, 2.0001427247692702, 2.0001141798154163, 2.000091343852333, 2.0000730750818665, 2.0000584600654934, 2.000046768052395, 2.0000374144419157, 2.0000299315535326, 2.000023945242826, 2.0000191561942606, 2.0000153249554087, 2.000012259964327, 2.0000098079714617, 2.0000078463771693, 2.0000062771017353, 2.000005021681388, 2.0000040173451104, 2.0000032138760884]
# [1.6, 1.2800000000000002, 1.024, 0.8192, 0.6553599999999999, 0.524288, 0.4194303999999999, 0.3355443199999999, 0.2684354559999999, 0.21474836479999998, 0.17179869183999996, 0.13743895347199997, 0.10995116277759998, 0.08796093022207999, 0.07036874417766396, 0.05629499534213114, 0.045035996273704894, 0.036028797018963936, 0.02882303761517111, 0.023058430092136907, 0.018446744073709543, 0.014757395258967599, 0.011805916207174062, 0.009444732965739267, 0.007555786372591378, 0.0060446290980730845, 0.004835703278458503, 0.0038685626227668024, 0.0030948500982134423, 0.002475880078570736, 0.001980704062856553, 0.0015845632502852426, 0.0012676506002281763, 0.0010141204801825232, 0.0008112963841460541, 0.0006490371073168078, 0.0005192296858534285, 0.00041538374868270726, 0.0003323069989461303, 0.00026584559915692195, 0.00021267647932550205, 0.00017014118346043717, 0.00013611294676838526, 0.00010889035741472597, 8.711228593174526e-05, 6.968982874537844e-05, 5.5751862996267223e-05, 4.460149039697825e-05, 3.56811923175826e-05, 2.8544953854048318e-05, 2.283596308325642e-05, 1.8268770466622897e-05, 1.4615016373298318e-05, 1.1692013098674181e-05, 9.35361047895711e-06, 7.482888383147923e-06, 5.986310706518339e-06, 4.789048565179144e-06, 3.831238852125551e-06, 3.0649910817359683e-06, 2.4519928653710113e-06, 1.961594292332336e-06, 1.569275433865869e-06, 1.255420347057168e-06, 1.0043362776102072e-06, 8.034690220704022e-07]
# [63, 39.96, 25.2144, 15.777216000000003, 9.737418239999997, 5.871947673599998, 3.398046511103999, 1.8147497671065587, 0.8014398509481975, 0.15292150460684617, -0.2621302370516183, -0.5277633517130358, -0.6977685450963431, -0.806571868861659, -0.8762059960714623, -0.9207718374857361, -0.9492939759908712, -0.9675481446341578, -0.9792308125658611, -0.9867077200421512, -0.9914929408269764, -0.9945554821292646, -0.9965155085627293, -0.9977699254801466, -0.998572752307294, -0.999086561476668, -0.9994153993450681, -0.9996258555808435, -0.9997605475717393, -0.9998467504459132, -0.9999019202853843, -0.9999372289826463, -0.9999598265488938, -0.9999742889912921, -0.9999835449544268, -0.9999894687708331, -0.9999932600133334, -0.9999956864085329, -0.9999972393014609, -0.9999982331529349, -0.9999988692178787, -0.9999992762994419, -0.999999536831643, -0.9999997035722519, -0.9999998102862406, -0.9999998785831945, -0.9999999222932443, -0.999999950267676, -0.9999999681713128, -0.9999999796296404, -0.9999999869629699, -0.9999999916563009, -0.9999999946600324, -0.9999999965824209, -0.9999999978127496, -0.9999999986001598, -0.9999999991041024, -0.9999999994266258, -0.9999999996330402, -0.9999999997651461, -0.9999999998496936, -0.9999999999038041, -0.9999999999384341, -0.9999999999605977, -0.9999999999747828, -0.9999999999838609]
# 66

# %%
## Gradient Descent Algo with Toelrance - Question 3 (Final)
# Function to define the cost function
def cost_function(x):
  return ((x ** 2) - (4*x) + 3)

#function to define the slope or first derivative
def grad_slope(x):
  return (2*x - 4)

#function to find out gradient descent in iterative mode to keep moving towards the zero slope
def gradient_descent(J, dJ, x, alpha, tol, max_iters):
  #create a blank list and initialize with intial scalar parameter
  List_x = [x]
  List_Improvement = []

  #iteration for indefinitely until we hit tolerance value
  while(True):
    #find the slope at initial scalar value x
    dJ = grad_slope(x)

    #subtracting value of x by multiplying its slope with learning rate in the direction to minimize the cost
    x = x - alpha * dJ

    #Recording improvement from the previous step
    List_Improvement.append(alpha * dJ)
    # Add updated value of x in the output list
    List_x.append(x)

    #Break the loop if the improvement is less than the tolerance value
    if(alpha * grad < tol):
      break

  # Print all the value of x that shows the gradient descent towards the minima / zero slope
  print(List_x)

  x_final = x
  J_history = List_x
  return x_final,J_history
